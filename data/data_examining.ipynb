# %%
import pandas as pd

df_load= pd.read_csv('load_data.csv')

# %%
df_load.sort_values(by=['TIMESTAMP']).tail(30)
# Out:
#                  TIMESTAMP  ZONEID   LOAD  w1  w2  w3  w4  w5  w6  w7  ...  \
# 93376  2011-12-08 18:00:00       1  154.7  52  43  42  50  50  43  49  ...
# 93377  2011-12-08 19:00:00       1  175.9  42  36  39  46  46  40  40  ...
# 93378  2011-12-08 20:00:00       1  181.5  45  34  38  42  42  40  39  ...
# 93379  2011-12-08 21:00:00       1  186.6  34  30  37  43  40  41  35  ...
# 93380  2011-12-08 22:00:00       1  188.9  32  30  34  41  38  37  35  ...
# 93381  2011-12-08 23:00:00       1  186.6  30  36  32  35  35  37  33  ...
# 93382  2011-12-09 00:00:00       1  181.4  29  34  32  37  41  35  34  ...
# 93383  2011-12-09 01:00:00       1  178.2  28  30  29  33  37  30  31  ...
# 93384  2011-12-09 02:00:00       1  179.8  27  27  27  33  35  32  29  ...
# 93385  2011-12-09 03:00:00       1  184.4  26  25  26  32  32  30  29  ...
# 93386  2011-12-09 04:00:00       1  190.1  24  25  25  29  32  30  29  ...
# ...

# %%
# check shape of load data
df_load.shape
# Out:
# (95663, 27)

# %%
# check if there is duplicate timestamp
df_load['TIMESTAMP'].duplicated().sum()
# Out:
# np.int64(4537)

# %%
df_load[df_load['TIMESTAMP']=="2010-12-01 01:00:00"]
# Out:
#                  TIMESTAMP   LOAD  w1  w2  w3  w4  w5  w6  w7  w8  ...  w16  \
# 720    2010-12-01 01:00:00   88.8  71  64  49  63  70  65  66  68  ...   67
# 81503  2010-12-01 01:00:00  142.6  50  38  43  53  54  41  41  54  ...   52
#
#        w17  w18  w19  w20  w21  w22  w23  w24  w25
# 720     63   67   64   66   65   64   69   67   65
# 81503   44   45   41   43   37   39   48   41   39
#
# [2 rows x 27 columns]

# %%
df_load[df_load['TIMESTAMP'].duplicated(keep=False)]
# Out:
#                TIMESTAMP   LOAD  w1  w2  w3  w4  w5  w6  w7  w8  ...  w16  \
# 720  2010-12-01 01:00:00   88.8  71  64  49  63  70  65  66  68  ...   67
# 721  2010-12-01 02:00:00   82.9  67  64  48  59  71  66  67  70  ...   68
# 722  2010-12-01 03:00:00   82.0  63  64  41  56  70  64  67  70  ...   68
# 723  2010-12-01 04:00:00   81.1  59  64  39  54  70  64  68  70  ...   70
# 724  2010-12-01 05:00:00   83.3  54  64  37  52  70  65  68  70  ...   68
# 725  2010-12-01 06:00:00   91.8  53  64  36  49  64  66  68  61  ...   67
# 726  2010-12-01 07:00:00  111.1  49  66  34  46  60  66  67  60  ...   68
# 727  2010-12-01 08:00:00  113.6  48  66  32  43  57  68  67  57  ...   63
# 728  2010-12-01 09:00:00  108.3  47  63  31  44  55  68  68  55  ...   61
# 729  2010-12-01 10:00:00  108.1  48  61  32  46  56  69  65  57  ...   58
# 730  2010-12-01 11:00:00  108.3  48  61  34  48  56  65  62  56  ...   60
# 731  2010-12-01 12:00:00  107.7  49  63  35  50  54  65  64  54  ...   61
# ...
