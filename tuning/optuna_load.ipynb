# %%
import optuna
import matplotlib.pyplot as plt
import numpy as np
from optuna.visualization.matplotlib import (
    plot_optimization_history,
    plot_param_importances,
    plot_slice,
    plot_contour,
    plot_edf,
)
import warnings
warnings.filterwarnings("ignore", category=optuna.exceptions.ExperimentalWarning)

# %% [markdown]
# ## GAN

# %%
study = optuna.load_study(
    study_name="load",
    storage="sqlite:///gan_study.db"
)

# %%
print("Best trial:", study.best_trial.number)
print("Best value:", study.best_value)
print("Best params:", study.best_trial.params)
# Out:
# Best trial: 3
# Best value: 0.4339573085308075
# Best params: {'n_critic': 9, 'gp_lambda': 11.16397179490632, 'd_lr': 0.005842681096339225, 'g_lr': 0.0017674389197537305, 'z_dim': 256, 'hidden_dim': 64}

# %%
fig = plot_optimization_history(study)
fig.figure.savefig("plots/hpo_optimization_history_gan_LOAD.png")
plt.show()

# %%
fig = plot_param_importances(study)
fig.figure.savefig("plots/hpo_param_importances_gan_LOAD.png")
plt.show()

# %%
labels = ['d_lr', 'g_lr', 'gp_lambda', 'hidden_dim', 'n_critic', 'z_dim']

axes = plot_contour(study, params=labels)  # returns numpy.ndarray of Axes
fig = axes.ravel()[0].figure               # get the figure
nrows, ncols = axes.shape

for (i, j), ax in np.ndenumerate(axes):
    # show x-labels only on bottom row
    if i != nrows - 1:
        ax.set_xlabel("")
        ax.set_xticklabels([])
    else:
        for t in ax.get_xticklabels():
            t.set_rotation(90)
            t.set_ha('center')

    # show y-labels only on left column
    if j != 0:
        ax.set_ylabel("")
        ax.set_yticklabels([])
    else:
        for t in ax.get_yticklabels():
            t.set_rotation(0)
            t.set_va('center')

# increase figure size
fig.set_size_inches(10, 10)
plt.savefig("plots/hpo_contour_gan_LOAD.png")


plt.show()

# %%
fig = plot_edf(study)
fig.figure.savefig("plots/hpo_edf_gan_LOAD.png")
plt.show()

# %%
fig = plot_slice(study)
fig[3].set_xticklabels(fig[3].get_xticklabels(), rotation=90)
plt.savefig("plots/hpo_slice_gan_LOAD.png")
plt.show()
# Out:
# /tmp/ipykernel_248349/263913557.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig[3].set_xticklabels(fig[3].get_xticklabels(), rotation=90)

# %% [markdown]
# ## VAE

# %%
study = optuna.load_study(
    study_name="load",
    storage="sqlite:///vae_study.db"
)

# %%
print("Best trial:", study.best_trial.number)
print("Best value:", study.best_value)
print("Best params:", study.best_trial.params)
# Out:
# Best trial: 15
# Best value: 0.3350091874599457
# Best params: {'latent_s': 32, 'enc_w': 64, 'enc_l': 4, 'dec_w': 128, 'dec_l': 3, 'lr': 0.0005671446362223727}

# %%
fig = plot_optimization_history(study)
fig.figure.savefig("plots/hpo_optimization_history_vae_LOAD.png")
plt.show()

# %%
fig = plot_param_importances(study)
fig.figure.savefig("plots/hpo_param_importances_vae_LOAD.png")
plt.show()

# %%
labels = ['latent_s', 'enc_w', 'enc_l', 'dec_w', 'dec_l', 'lr']

axes = plot_contour(study, params=labels)  # returns numpy.ndarray of Axes
fig = axes.ravel()[0].figure               # get the figure
nrows, ncols = axes.shape

for (i, j), ax in np.ndenumerate(axes):
    # show x-labels only on bottom row
    if i != nrows - 1:
        ax.set_xlabel("")
        ax.set_xticklabels([])
    else:
        for t in ax.get_xticklabels():
            t.set_rotation(90)
            t.set_ha('center')

    # show y-labels only on left column
    if j != 0:
        ax.set_ylabel("")
        ax.set_yticklabels([])
    else:
        for t in ax.get_yticklabels():
            t.set_rotation(0)
            t.set_va('center')

# increase figure size
fig.set_size_inches(10, 10)
plt.savefig("plots/hpo_contour_vae_LOAD.png")

plt.show()

# %%
fig = plot_edf(study)
fig.figure.savefig("plots/hpo_edf_vae_LOAD.png")
plt.show()

# %%
fig = plot_slice(study)
plt.savefig("plots/hpo_slice_vae_LOAD.png")
plt.show()

# %% [markdown]
# ## NAF

# %%
study = optuna.load_study(
    study_name="load",
    storage="sqlite:///naf_study.db"
)

# %%
print("Best trial:", study.best_trial.number)
print("Best value:", study.best_value)
print("Best params:", study.best_trial.params)
# Out:
# Best trial: 12
# Best value: 0.1422157734632492
# Best params: {'n_layers': 3, 'width_exp': 4, 'transforms': 2, 'lr': 0.0009777286010220912}

# %%
fig = plot_optimization_history(study)
fig.figure.savefig("plots/hpo_optimization_history_naf_LOAD.png")
plt.show()

# %%
fig = plot_param_importances(study)
fig.figure.savefig("plots/hpo_param_importances_naf_LOAD.png")
plt.show()

# %%
labels = ['n_layers', 'width_exp', 'transforms', 'lr']

axes = plot_contour(study, params=labels)  # returns numpy.ndarray of Axes
fig = axes.ravel()[0].figure               # get the figure
nrows, ncols = axes.shape

for (i, j), ax in np.ndenumerate(axes):
    # show x-labels only on bottom row
    if i != nrows - 1:
        ax.set_xlabel("")
        ax.set_xticklabels([])
    else:
        for t in ax.get_xticklabels():
            t.set_rotation(90)
            t.set_ha('center')

    # show y-labels only on left column
    if j != 0:
        ax.set_ylabel("")
        ax.set_yticklabels([])
    else:
        for t in ax.get_yticklabels():
            t.set_rotation(0)
            t.set_va('center')

# increase figure size
fig.set_size_inches(10, 10)
plt.savefig("plots/hpo_contour_naf_LOAD.png")


plt.show()

# %%
fig = plot_edf(study)
fig.figure.savefig("plots/hpo_edf_naf_LOAD.png")
plt.show()

# %%
fig = plot_slice(study)
plt.savefig("plots/hpo_slice_naf_LOAD.png")
plt.show()

# %% [markdown]
# ## NSF

# %%
study = optuna.load_study(
    study_name="load",
    storage="sqlite:///nsf_study.db"
)

# %%
print("Best trial:", study.best_trial.number)
print("Best value:", study.best_value)
print("Best params:", study.best_trial.params)
# Out:
# Best trial: 18
# Best value: 0.15642274916172028
# Best params: {'n_layers': 3, 'width_exp': 5, 'transforms': 3, 'lr': 0.0017499867268076512}

# %%
fig = plot_optimization_history(study)
fig.figure.savefig("plots/hpo_optimization_history_nsf_LOAD.png")
plt.show()

# %%
fig = plot_param_importances(study)
fig.figure.savefig("plots/hpo_param_importances_nsf_LOAD.png")
plt.show()

# %%
labels = ['n_layers', 'width_exp', 'transforms', 'lr']


axes = plot_contour(study, params=labels)  # returns numpy.ndarray of Axes
fig = axes.ravel()[0].figure               # get the figure
nrows, ncols = axes.shape

for (i, j), ax in np.ndenumerate(axes):
    # show x-labels only on bottom row
    if i != nrows - 1:
        ax.set_xlabel("")
        ax.set_xticklabels([])
    else:
        for t in ax.get_xticklabels():
            t.set_rotation(90)
            t.set_ha('center')

    # show y-labels only on left column
    if j != 0:
        ax.set_ylabel("")
        ax.set_yticklabels([])
    else:
        for t in ax.get_yticklabels():
            t.set_rotation(0)
            t.set_va('center')

# increase figure size
fig.set_size_inches(10, 10)
plt.savefig("plots/hpo_contour_nsf_LOAD.png")

plt.show()

# %%
fig = plot_edf(study)
fig.figure.savefig("plots/hpo_edf_nsf_LOAD.png")
plt.show()

# %%
fig = plot_slice(study)
plt.savefig("plots/hpo_slice_nsf_LOAD.png")
plt.show()
